# %% [markdown]
# # Object Oriented Programming With Python

# %% [markdown]
#     It is an object-oriented language.

# %% [markdown]
# ## OOPS Concepts(Object Oriented Programming System Concepts)

# %% [markdown]
# ### 1)Data Encapsulation

# %% [markdown]
#     Wrapping of data and methods into a single unit is called Data Encapsulation.

# %% [markdown]
# ### 2)Data Hiding

# %% [markdown]
# #### Two reasons to hide the data
#     1)To provide the security
#     2)To reduce the complexity of the object

# %% [markdown]
# ### 3)Inheritance

# %% [markdown]
#     new object = exiting + new features
#     object----data and functions---existing object
#     new object------new data and functions
#
# #### Inheritance provides the re usability of code.
#
# #### Advantages
#     1)Duplicate coding--- reduce
#     2)Program length--- reduce
#     3)Memory saving
#     4)Time saving

# %% [markdown]
# ### 4)Polymorphism

# %% [markdown]
#     It is an ability to take more than one form.
#
#     One thing multiple forms or one thing multiple behavior.
#
#     Method overloading or Function overloading-----Example of Polymorphism

# %% [markdown]
# ### 5)Data Abstraction

# %% [markdown]
#     It is an act of representing essential features without including background details.

# %% [markdown]
# ### Object Oriented Programming
# #### Object Oriented analysis

# %% [markdown]
# #### 1)To identify the two types of objects in your system.
#     1)physical object
#     2)conceptual object
#
#
#     physical object----Student,Employee,Book
#     conceptual object---order, transaction

# %% [markdown]
# #### 2)To identify the properties of each object.
#
#     Properties or attributes or data or variables
#
#     Student------rollno,name,address,Phoneno
#     Employee---code no,department,salary
#     Order----order id, order date, product description, price, quantity
#     Transaction---trasacid, trndate,trnamt

# %% [markdown]
# #### 3)To identify the functions of an objects.
#     functions or methods or operations or behavior
#
#     Student-----getData(),showData(),getPer()

# %% [markdown]
# ### Class

# %% [markdown]
#     It is a general form or blueprint or template which defines the shape and behavior of an object.
#
#     shape-----properties or attributes or data or variables
#     behavior---functions or methods or operations

# %% [markdown]
# ### Object
#     Once a class has been defined you can create a physical instance of that class and that is called an object of that class.
#
#     The attributes are data members (instance variables) and instance methods, accessed via dot notation.

# %% [markdown]
# ### Two Types of Variables

# %% [markdown]
# #### Class variable
#     A variable that is shared by all instances of a class. Class variables are defined within a class but outside any of the class's methods.
#
# #### Instance variable
#     A variable that is defined inside a method and belongs only to the current instance of a class.

# %% [markdown]
# ### Declaration Of Class
#
# #### Syntax
#     class ClassName:
#         'Optional class documentation string'
#         class_code
#
#     The class has a documentation string, which can be accessed via ClassName.__doc__.
#
#     The class_code consists of all the component statements defining class members, data attributes and functions.
#
#     You declare other class methods like normal functions with the exception that the first argument to each method is self. Python adds the self argument to the list for you; you do not need to include it when you call the methods.

# %% [markdown]
# ### Instance or Object
#
#     To create instances of a class, you call the class using class name and pass in whatever arguments its __init__ method accepts(Constructer).
#
#     emp1 = Employee()-----Object with No Parameters
#
#     emp2 = Employee()-----Object with No Parameters
#
#     emp1 = Employee("Zara", 2000)-----Object with two Parameters
#
#     emp2 = Employee("Manni", 5000)-----Object with two Parameters

# %% [markdown]
# ### Built-In Class Attributes
#
#     Every Python class keeps following built-in attributes and they can be accessed using dot operator like any other attribute
#
#     __dict__ − Dictionary containing the class's namespace.
#     __doc__ − Class documentation string or none, if undefined.
#     __name__ − Class name.
#     __module__ − Module name in which the class is defined. This attribute is "__main__" in interactive mode.
#     __bases__ − A possibly empty tuple containing the base classes, in the order of their occurrence in the base class list.

# %%
#FIRST oBJECT ORIENTED PROGRAM
class Rectangle:
    "It is class that represents rectangle Object"
    def __init__(self,w,h):#paramerised constructor to initialize the object
        self.width=w
        self.height=h
        print("I am constructor of rectangle class")
    def area(self):
        print("Area of rectangle is ",(self.height*self.width))
    def perimeter(self):
        print("Perimeter of rectangle is ",(2*self.height)+(2*self.width))
    def setWidth(self,w):#setter method
        if w>=0:
            self.width=w
        else:
            print("Width should not be negative")
    def setHeight(self,h):#setter method
        if h>=0:
            self.height=h
        else:
            print("Height should not be negative")
        
    def getWidth(self):#getter method
        return self.width
    def getHeight(self):#getter method
        return self.height
    def __del__(self):#destructor to destroy the object
        print("i am destructor of rectangle class")
    def __str__(self):#it is called automatically when you print rectangle object
        return "Rectangle("+str(self.width)+","+str(self.height)+")"
    
    
    
r1=Rectangle(20,10)
r1.area()
r1.perimeter()
r1.setWidth(40)
r1.setHeight(40)
print(r1.getWidth())
print(r1.getHeight())
print(r1)

r1.area()
r1.perimeter()


r2=Rectangle(200,100)
r2.area()
r2.perimeter()
r2.setHeight(150)
print(r2.getHeight())
r2.area()
r2.perimeter()
print(r2)

r1=Rectangle(10,10)
r2=Rectangle(10,10)
print(r1)
print(r2)
print("metadata of Rectangle class")
print ("Rectangle.__doc__:", Rectangle.__doc__)
print ("Rectanglet.__name__:", Rectangle.__name__)
print ("Rectanglet.__module__:", Rectangle.__module__)
print ("Rectanglet.__bases__:", Rectangle.__bases__)
print ("Rectangle.__dict__:", Rectangle.__dict__)
# Out:
# I am constructor of rectangle class
# Area of rectangle is  200
# Perimeter of rectangle is  60
# 40
# 40
# Rectangle(40,40)
# Area of rectangle is  1600
# Perimeter of rectangle is  160
# I am constructor of rectangle class
# Area of rectangle is  20000
# Perimeter of rectangle is  600
# 150
# Area of rectangle is  30000
# Perimeter of rectangle is  700
# Rectangle(200,150)
# I am constructor of rectangle class
# i am destructor of rectangle class
# I am constructor of rectangle class
# i am destructor of rectangle class
# Rectangle(10,10)
# Rectangle(10,10)
# metadata of Rectangle class
# Rectangle.__doc__: It is class that represents rectangle Object
# Rectanglet.__name__: Rectangle
# Rectanglet.__module__: __main__
# Rectanglet.__bases__: (<class 'object'>,)
# ...

# %%
class Operation:
    "It is class that represnts basic operations on any number"
    def __init__(self,no):
        self.no=no
        print("i am constructor")
    def setNo(self,no):
        if no>=0:
            self.no=no
        else:
            print("No negative value allowed")
    def getNo(self):
        return self.no;
    def __del__(self):
        print("i am destructor")
    def __str__(self):
        return "Number is "+str(self.no)
    def sumofdigit(self):
        temp=self.no
        sum=0
        while(temp>0):
            rem=temp%10;
            sum=sum+rem
            temp=temp//10
        return sum
    
    def isarmstrong(self):
        temp=self.no
        sum=0
        while(temp>0):
            rem=temp%10;
            sum=sum+(rem**3)
            temp=temp//10
        if(sum==self.no):
            return True
        else:
            return False
        
    def ispallendrome(self):
        temp=self.no
        revno=0
        while(temp>0):
            rem=temp%10;
            revno=(revno*10)+rem
            temp=temp//10
        if(revno==self.no):
            return True
        else:
            return False
        
    def reversenumber(self):
        temp=self.no
        revno=0
        while(temp>0):
            rem=temp%10;
            revno=(revno*10)+rem
            temp=temp//10
        return revno
    def isprime(self):
        flag=0
        for i in range(2,self.no):
            if self.no%i==0:
                flag=1
                break;
        if flag:
            return False
        else:
            return True

o1=Operation(153)
if o1.isarmstrong():
    print("It is an armstrong number")
else:
    print("It is not an armstrong number")

if o1.isprime():
    print("It is a prime number")
else:
    print("It is not a prime number")
    
sum=o1.sumofdigit()
print("The sum of digit is ",sum)
revno=o1.reversenumber()
print("The reverse number is ",revno)
if o1.ispallendrome():
    print("It is a pallendrome number")
else:
    print("It is not a pallendrome number")

o1.setNo(307)
print(o1.getNo())
print(o1)
del o1
# Out:
# i am constructor
# It is an armstrong number
# It is not a prime number
# The sum of digit is  9
# The reverse number is  351
# It is not a pallendrome number
# 307
# Number is 307
# i am destructor

# %%
class Student:
    "It is a class that represent Student object"
    studentcount=0 #class variable
    def __init__(self):
        Student.studentcount+=1
        self.rollno=Student.studentcount
        self.name="jaysukh Patel"
        self.address="Naranpura"
        self.phone=9925849244
        self.maths=50
        self.sci=50
        self.eng=50
        self.total=150
        self.per=50.0
        self.grade="C++"
        print("I am constructor")
    def setdata1(self,n,a,p,m,s,e):
        
        self.name=n
        self.address=a
        self.phone=p
        self.maths=m
        self.sci=s
        self.eng=e
    def setdata2(self):
        
        self.name=input("Enter Name")
        self.address=input("Enter Address")
        self.phone=int(input("Enter Phone no"))
        self.maths=int(input("Enter Maths Marks"))
        self.sci=int(input("Enter Science Marks"))
        self.eng=int(input("Enter English Marks"))
    def showdata(self):
        print("Roll No ",self.rollno)
        print("Name ",self.name)
        print("Address ",self.address)
        print("Phone No ",self.phone)
        print("Maths ",self.maths)
        print("Science ",self.sci)
        print("English ",self.eng)
        print("Total ",self.total)
        print("Percentage ",self.per)
        print("Grade ",self.grade)
        
    def calgrade(self):
        self.total=self.maths+self.sci+self.eng
        self.per=self.total/3.0
        if self.per>=90:
            self.grade="A++"
        elif self.per>=80:
            self.grade="A--"
        elif self.per>=70:
            self.grade="B++"
        elif self.per>=60:
            self.grade="B--"
        elif self.per>=50:
            self.grade="C++"
        elif self.per>=40:
            self.grade="C--"
        else:
            self.grade="FAIL"
    
    def setname(self,n):
        self.name=n
    def setaddress(self,a):
        self.address=a
    def setphone(self,p):
        
        if(len(str(p))==10):
            self.phone=p
        else:
            print("It must be of 10 digis")
    def setmaths(self,m):
        if m>=0 and m<=100:
            self.maths=m
        else:
            print("Marks should be between 0 to 100")
    def setsci(self,s):
        self.sci=s
    def seteng(self,e):
        self.eng=e
    def getrollno(self):
        return self.rollno
    def getname(self):
        return self.name
    def getaddress(self):
        return self.address
    def getphone(self):
        return self.phone
    def getmaths(self):
        return self.maths
    def getsci(self):
        return self.sci
    def geteng(self):
        return self.eng
    def gettotal(self):
        return self.total
    def getper(self):
        return self.per
    def getgrade(self):
        return self.grade
    
    
            
s1=Student()
s2=Student()
s1.showdata()
s2.showdata()
s1.setdata1("kiran","isanpur",4554656,67,89,90)
s2.setdata1("Chirag","Maninagar",4578856,78,58,80)
s1.calgrade()
s2.calgrade()
s1.showdata()
s2.showdata()
s1.setdata2()
s2.setdata2()
s1.calgrade()
s2.calgrade()
s1.showdata()
s2.showdata()
s1.maths =67  #change maths marks for student 1
print("first student Maths = ",s1.maths)
s2.maths=90
print("second student Maths = ",s2.maths)
s1.setphone(546546476576546)
print(s1.getphone())
s1.setphone(1234565423)
print(s1.getphone())
s3=Student()
s4=Student()
s3.setdata2()
s4.setdata2()
s3.calgrade()
s4.calgrade()
s3.showdata()
s4.showdata()
print()
print("metadata of student class")
print ("Student.__doc__:", Student.__doc__)
print ("Student.__name__:", Student.__name__)
print ("Student.__module__:", Student.__module__)
print ("Student.__bases__:", Student.__bases__)
print ("Student.__dict__:", Student.__dict__)
# Out:
# I am constructor
# I am constructor
# Roll No  1
# Name  jaysukh Patel
# Address  Naranpura
# Phone No  9925849244
# Maths  50
# Science  50
# English  50
# Total  150
# Percentage  50.0
# Grade  C++
# Roll No  2
# Name  jaysukh Patel
# Address  Naranpura
# Phone No  9925849244
# Maths  50
# Science  50
# English  50
# Total  150
# Percentage  50.0
# Grade  C++
# Roll No  1
# Name  kiran
# Address  isanpur
# Phone No  4554656
# Maths  67
# Science  89
# English  90
# Total  246
# Percentage  82.0
# Grade  A--
# Roll No  2
# Name  Chirag
# Address  Maninagar
# Phone No  4578856
# Maths  78
# Science  58
# English  80
# Total  216
# Percentage  72.0
# Grade  B++
# Enter Namesirish
# Enter Addressnaranpura
# Enter Phone no5435444567
# Enter Maths Marks68
# Enter Science Marks89
# Enter English Marks93
# Enter Namehiren
# Enter Addressisanpur
# Enter Phone no3454354533
# Enter Maths Marks78
# Enter Science Marks90
# Enter English Marks82
# Roll No  1
# Name  sirish
# Address  naranpura
# ...

# %%
# Employee Object with class variable,automatic id generation,constructor overloading
class Employee:
   'Common base class for all employees'
   #is a class variable whose value is shared among all the
   #instances of a in this class.It can be accesed via classname
   empCount = 0 #class variable

   #is a special method, which is called class constructor.
   #It is called automatically when you create an instance of this class.
   
   def __init__(self, name="jay", salary=5000):#constructor overloading
      
      self.name = name   #instance variable
      self.salary = salary  #instance variable
      Employee.empCount += 1  #static or class variable
      self.id =Employee.empCount   #instance variable(automatic id generation)
   
   
   def displayCount(self):
     print ("Total Employee %d" % Employee.empCount)

   def displayEmployee(self):
      print ("Id : ",self.id,"Name : ", self.name,  ", Salary: ", self.salary)

emp1 = Employee("Zara", 2000)
emp2 = Employee("Manni", 5000)

emp1.displayEmployee()
emp2.displayEmployee()

print ("Total Employee %d" % Employee.empCount)
emp3 = Employee()
emp4 = Employee()

emp3.displayEmployee()
emp4.displayEmployee()
print ("Total Employee %d" % Employee.empCount)

emp5 = Employee("Lalit")
emp6 = Employee("Nirav")

emp5.displayEmployee()
emp6.displayEmployee()
print ("Total Employee %d" % Employee.empCount)

emp7 = Employee(salary=10000)
emp8 = Employee(salary=4000)

emp7.displayEmployee()
emp8.displayEmployee()
print ("Total Employee %d" % Employee.empCount)

print()
print("Metadata of employee class")
print ("Employee.__doc__:", Employee.__doc__)
print ("Employee.__name__:", Employee.__name__)
print ("Employee.__module__:", Employee.__module__)
print ("Employee.__bases__:", Employee.__bases__)
print ("Employee.__dict__:", Employee.__dict__)
# Out:
# Id :  1 Name :  Zara , Salary:  2000
# Id :  2 Name :  Manni , Salary:  5000
# Total Employee 2
# Id :  3 Name :  jay , Salary:  5000
# Id :  4 Name :  jay , Salary:  5000
# Total Employee 4
# Id :  5 Name :  Lalit , Salary:  5000
# Id :  6 Name :  Nirav , Salary:  5000
# Total Employee 6
# Id :  7 Name :  jay , Salary:  10000
# Id :  8 Name :  jay , Salary:  4000
# Total Employee 8
#
# Metadata of employee class
# Employee.__doc__: Common base class for all employees
# Employee.__name__: Employee
# Employee.__module__: __main__
# Employee.__bases__: (<class 'object'>,)
# ...

# %% [markdown]
# ### Destroying Objects (Garbage Collection)

# %% [markdown]
#     Python deletes unused objects (built-in types or class instances) automatically to free the memory space. The process by which Python periodically reclaims blocks of memory that no longer are in use is termed as Garbage Collection.
#
#     Python's garbage collector runs during program execution and is triggered when an object's reference count reaches zero. An object's reference count changes as the number of aliases that point to it changes.
#
#     An object's reference count increases when it is assigned a new name or placed in a container (list, tuple, or dictionary). The object's reference count decreases when it is deleted with del, its reference is reassigned, or its reference goes out of scope. When an object's reference count reaches zero, Python collects it automatically.
#
#     a = 40      # Create object <40>
#     b = a       # Increase ref. count  of <40>
#     c = [b]     # Increase ref. count  of <40>
#
#     del a       # Decrease ref. count  of <40>
#     b = 100     # Decrease ref. count  of <40>
#     c[0] = -1   # Decrease ref. count  of <40>
#
#     However, a class can implement the special method __del__(), called a destructor, that is invoked when the instance is about to be destroyed. This method might be used to clean up any non-memory resources used by an instance.

# %%
#Example of constructor and destructor
class Point:
   def __init__( self, x=0, y=0):#constructor overloading
      self.x = x
      self.y = y
      self.class_name = self.__class__.__name__
      print (self.class_name, "constructor is called")
   def __del__(self):
        print (self.class_name, "destrructor is called")
   def display(self):
        print ("X = ",self.x,"Y = ",self.y)

pt1 = Point()
pt1.display()
pt2 = pt1
pt3 = pt1
print (id(pt1), id(pt2), id(pt3)) # prints the ids of the obejcts
del pt1
del pt2
del pt3

pt4 = Point(23,56)
pt4.display()
pt5 = Point(23)
pt5.display()
del pt4
del pt5
# Out:
# Point constructor is called
# X =  0 Y =  0
# 2407346724624 2407346724624 2407346724624
# Point destrructor is called
# Point constructor is called
# X =  23 Y =  56
# Point constructor is called
# X =  23 Y =  0
# Point destrructor is called
# Point destrructor is called

# %% [markdown]
# ### Pandas

# %% [markdown]
# Why Pandas?
# * Simple to use
# * Integrating to so many Data Science libraries & ML Python tools
# * Helps to get your data ready for analysis and Ml
# * Fast! all thanks to C (Numpy)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing 
import pandas as pd
import numpy as np

# %%
# 2 main data-types
series = pd.Series(["BMW","Mercedes","Audi"])
series
# Out:
# 0         BMW
# 1    Mercedes
# 2        Audi
# dtype: object

# %%
# series = 1-Dimensional column of Information
colours = pd.Series(["Red","Green","Blue"])
colours
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# DataFrame is 2-Dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#    Car make Colour
# 0       BMW    Red
# 1  Mercedes  Green
# 2      Audi   Blue

# %%
# importing csv
car_sales = pd.read_csv("Data/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Describe data

# %%
# Attribute
car_sales.dtypes

# Method(similiar to function)
#car_sales.to_csv("newfile.csv")
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\Rutaben\AppData\Local\Temp/ipykernel_11512/3099523788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# 786014

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.shape
# Out:
# (10, 5)

# %% [markdown]
# ### Viewing and selecting data

# %%
# first 5 rows
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# last 5 rows
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# .loc & .iloc
# Loc - refers to name of index && Iloc - refers to position of index
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.iloc[2:5]
# Out:
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_shuffled = car_sales.sample(n=6)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 5  Toyota  Green          99213      4   $4,500.00
# 9  Nissan  White          31600      4   $9,700.00
# 3     BMW  Black          11179      5  $22,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 0  Toyota  White         150043      4   $4,000.00

# %%
# grabbing columns
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# check between . and [""] with odometer col
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# filter out data to get only toyota makers
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[(car_sales["Odometer (KM)"] >= 60000) & (car_sales["Odometer (KM)"] <= 100000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 1   Honda    Red          87899      4  $5,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Create a cross tabulation/frequency table
df=pd.crosstab(index=car_sales["Make"],columns=car_sales["Doors"])

df
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Create a cross tabulation/frequency table
df=pd.crosstab(index=car_sales["Colour"],columns=car_sales["Make"])

df
# Out:
# Make    BMW  Honda  Nissan  Toyota
# Colour
# Black     1      0       0       0
# Blue      0      2       0       1
# Green     0      0       0       1
# Red       0      1       0       0
# White     0      0       2       2

# %%
df.loc["Green"]
# Out:
# Make
# BMW       0
# Honda     0
# Nissan    0
# Toyota    1
# Name: Green, dtype: int64

# %%
df.loc["Red"]
# Out:
# Make
# BMW       0
# Honda     1
# Nissan    0
# Toyota    0
# Name: Red, dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby(["Make"])["Doors"].mean()
# Out:
# Make
# BMW       5.00
# Honda     4.00
# Nissan    4.00
# Toyota    3.75
# Name: Doors, dtype: float64

# %%
car_sales.groupby(["Colour"]).mean().sort_values(by="Doors",ascending=False)
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000
# Blue     44328.333333  3.666667

# %%
# group by multiple heirarchies
car_sales.groupby(["Make","Colour"]).mean()
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# BMW    Black         11179.0    5.0
# Honda  Blue          50218.0    4.0
#        Red           87899.0    4.0
# Nissan White        122347.5    4.0
# Toyota Blue          32549.0    3.0
#        Green         99213.0    4.0
#        White        105021.5    4.0

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# pandas plotting
car_sales["Odometer (KM)"].plot(figsize=(10,5));

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
# change price column to numeric
def custom(row):
    return row.replace("$",'').replace(",",'')

car_sales.Price.apply(custom).astype(float)
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
car_sales.Price = car_sales.Price.apply(custom).astype(float)

# %%
car_sales.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)      int64
# Doors              int64
# Price            float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.Price.plot(figsize=(12,5));

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales["Odometer (KM)"].hist(figsize=(12,5),bins=100);

# %% [markdown]
# #### Explore 2 more ways to do the same thing --> Using Lambda function & Using Regex instead of replace

# %%
# soln

# %% [markdown]
# ### Manipulating data

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0

# %%
# Missing data
car_sales_missing = pd.read_csv('Data/car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_missing.isnull().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
# handle missing values

# repalce with mean
mean_val = car_sales_missing.Odometer.mean()
car_sales_missing.Odometer.fillna(mean_val,inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# drop missing values
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# ##### Creating and adding new column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
# column from series
seats = pd.Series([5,5,5,5,5])

car_sales["Seats"] = seats

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales.Seats.fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
# Column from Python list

fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5

# %%
# Columns from other columns

car_sales["Total fuel used"] = (car_sales["Odometer (KM)"]/100) * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         4762.206
# ...

# %%
car_sales["Doors_to_seat_ratio"] = car_sales["Doors"] / car_sales["Seats"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Doors_to_seat_ratio
# 0        11253.225                  0.8
# 1         8086.708                  0.8
# 2         1627.450                  0.6
# ...

# %%
# create a column from single value
car_sales["Passed safety measures"] = True
car_sales["No.of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures  No.of Wheels
# 0        11253.225                  0.8                    True             4
# ...

# %%
# drop a column
car_sales.drop("No.of Wheels",axis=1,inplace=True)  # 0-->rows | 1-->columns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 0        11253.225                  0.8                    True
# ...

# %%
# drop a row
car_sales.drop([2,4,5,6,7])  #index of the rows to remove
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 0        11253.225                  0.8                    True
# 1         8086.708                  0.8                    True
# 3         1073.184                  1.0                    True
# 8         1800.000                  0.8                    True
# 9         1422.000                  0.8                    True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 0        11253.225                  0.8                    True
# ...

# %%
car_sales['Colour']=='White'
car_sales[car_sales['Colour']=='White'].index
# Out:
# Int64Index([0, 4, 8, 9], dtype='int64')

# %%
car_sales.drop(car_sales[car_sales['Colour']=='White'].index, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 1         8086.708                  0.8                    True
# 2         1627.450                  0.6                    True
# 3         1073.184                  1.0                    True
# 5         4663.011                  0.8                    True
# 6         3473.048                  0.8                    True
# 7         4762.206                  0.8                    True

# %%
# sample
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 1         8086.708                  0.8                    True
# 7         4762.206                  0.8                    True
# 5         4663.011                  0.8                    True
# 6         3473.048                  0.8                    True
# 2         1627.450                  0.6                    True
# 3         1073.184                  1.0                    True

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      1   honda    Red          87899      4   5000.0    5.0             9.2
# 1      7   honda   Blue          54738      4   7000.0    5.0             8.7
# 2      5  toyota  Green          99213      4   4500.0    5.0             4.7
# 3      6   honda   Blue          45698      4   7500.0    5.0             7.6
# 4      2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 5      3     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 0         8086.708                  0.8                    True
# 1         4762.206                  0.8                    True
# 2         4663.011                  0.8                    True
# 3         3473.048                  0.8                    True
# 4         1627.450                  0.6                    True
# ...

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0   honda    Red          87899      4   5000.0    5.0             9.2
# 1   honda   Blue          54738      4   7000.0    5.0             8.7
# 2  toyota  Green          99213      4   4500.0    5.0             4.7
# 3   honda   Blue          45698      4   7500.0    5.0             7.6
# 4  toyota   Blue          32549      3   7000.0    5.0             5.0
# 5     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 0         8086.708                  0.8                    True
# 1         4762.206                  0.8                    True
# 2         4663.011                  0.8                    True
# 3         3473.048                  0.8                    True
# 4         1627.450                  0.6                    True
# 5         1073.184                  1.0                    True

# %%
car_sales_shuffled.set_index("Make",drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#        Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# Make
# bmw     Black          11179      5  22000.0    5.0             9.6
# honda     Red          87899      4   5000.0    5.0             9.2
# honda    Blue          54738      4   7000.0    5.0             8.7
# honda    Blue          45698      4   7500.0    5.0             7.6
# toyota   Blue          32549      3   7000.0    5.0             5.0
# toyota  Green          99213      4   4500.0    5.0             4.7
#
#         Total fuel used  Doors_to_seat_ratio  Passed safety measures
# Make
# bmw            1073.184                  1.0                    True
# honda          8086.708                  0.8                    True
# honda          4762.206                  0.8                    True
# honda          3473.048                  0.8                    True
# toyota         1627.450                  0.6                    True
# ...

# %% [markdown]
# ### Start from here

# %%
# unique & nunique
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
#
#    Total fuel used  Doors_to_seat_ratio  Passed safety measures
# 1         8086.708                  0.8                    True
# 2         1627.450                  0.6                    True
# 3         1073.184                  1.0                    True
# 5         4663.011                  0.8                    True
# 6         3473.048                  0.8                    True
# 7         4762.206                  0.8                    True

# %%
# value_counts
car_sales.Doors.value_counts()
# Out:
# 4    4
# 3    1
# 5    1
# Name: Doors, dtype: int64

# %%
car_sales.Make.value_counts()
# Out:
# honda     3
# toyota    2
# bmw       1
# Name: Make, dtype: int64

# %%
# nlargest,nsmallest
car_sales.Make.unique()
# Out:
# array(['honda', 'toyota', 'bmw'], dtype=object)

# %%
car_sales.Colour.unique()
# Out:
# array(['Red', 'Blue', 'Black', 'Green'], dtype=object)

# %%
car_sales.Doors.nlargest(2)
# Out:
# 3    5
# 1    4
# Name: Doors, dtype: int64

# %%
car_sales['Odometer (KM)'].nlargest(2)
# Out:
# 5    99213
# 1    87899
# Name: Odometer (KM), dtype: int64

# %%
car_sales['Odometer (KM)'].nsmallest(2)
# Out:
# 3    11179
# 2    32549
# Name: Odometer (KM), dtype: int64

# %% [markdown]
# ### Merging Dataframes

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')

# %%
staff_df.head()
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df.head()
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %% [markdown]
# A				    B
# id	firstname		id	dept
# 1	jay			    3	hr
# 2	kiran			4	reserch
# 3	lalit			5	main
# 4	mayur			6	pro
# 5	nilay			7	dd
#
# inner join-----
# 3 lalit	 3	hr
# 4 mayur  4	reserch
# 5 nilay 5 	maintanance
#
# left outer join-result of inner join+unmatching rows from left table
# 3 lalit	 3	hr
# 4 mayur  4	reserch
# 5 nilay 5 	maintanance
# 1 jay	null	null
# 2 kiran null	null
#
# right outer join-result of inner join+unmatching rows from right table
# 3 lalit	 3	hr
# 4 mayur  4	reserch
# 5 nilay 5 	maintanance
# null null 6	pro
# null null 7	dd
#
# full outer join-result of inner join+unmatching rows from right table+unmatching rows from left table
# 3 lalit	 3	hr
# 4 mayur  4	reserch
# 5 nilay 5 	maintanance
# null null 6	pro
# null null 7	dd
# 1 jay	null	null
# 2 kiran null	null

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %% [markdown]
# ##### Merging on 2 columns

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])

# %%
staff_df
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader

# %%
student_df
# Out:
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', left_on=['First Name'], right_on=['First Name'])
# Out:
#   First Name Last Name_x            Role Last Name_y       School
# 0      Sally      Brooks  Course liasion      Brooks  Engineering
# 1      James       Wilde          Grader     Hammond     Business

# %%
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# ### Pivot tables

# %%
car_sales2 = pd.read_csv("./Data/car-sales-2.csv")
car_sales2.head(5)
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
car_sales2.pivot_table(index="Make",columns="YEAR",values='(kW)',aggfunc="mean")
# Out:
# YEAR        2012   2013        2014        2015   2016
# Make
# BMW          NaN    NaN         NaN  125.000000  125.0
# CHEVROLET    NaN    NaN  104.000000  104.000000  104.0
# FORD         NaN  107.0  107.000000  107.000000  107.0
# KIA          NaN    NaN         NaN   81.000000   81.0
# MITSUBISHI  49.0   49.0   49.000000   49.000000   49.0
# NISSAN      80.0   80.0   80.000000   80.000000   80.0
# SMART        NaN   35.0   35.000000   35.000000   35.0
# TESLA        NaN  280.0  268.333333  320.666667  409.7

# %%
car_sales2.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=[np.mean,np.min],margins=True )
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# ...

# %%
car_sales2.to_excel('my.xlsx')

# %%
car_sales = pd.read_csv("./Data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.boxplot(by='Colour')
# Out:
# array([<AxesSubplot:title={'center':'Doors'}, xlabel='[Colour]'>,
#        <AxesSubplot:title={'center':'Odometer (KM)'}, xlabel='[Colour]'>],
#       dtype=object)
